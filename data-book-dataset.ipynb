# %%
#Importing important libraries 
import numpy as np 

import pandas as pd

# %%
# Importing Dataset
df=pd.read_csv('C:/Users/ahed/Desktop/kindle_data-v2.csv')
df.head(10)
# Out:
#          asin                                              title  \
# 0  B00TZE87S4  Adult Children of Emotionally Immature Parents...
# 1  B08WCKY8MB  From Strength to Strength: Finding Success, Ha...
# 2  B09KPS84CJ  Good Inside: A Guide to Becoming the Parent Yo...
# 3  B07S7QPG6J             Everything I Know About Love: A Memoir
# 4  B00N6PEQV0  The Seven Principles for Making Marriage Work:...
# 5  B000OVLKMM                         The Glass Castle: A Memoir
# 6  B00AEBEQUK  Expecting Better: Why the Conventional Pregnan...
# 7  B0BN5742KY  Never Enough: When Achievement Culture Becomes...
# 8  B098PXH8CK  Unmasking Autism: Discovering the New Faces of...
# 9  B087D5YQXB  What Happened to You?: Conversations on Trauma...
#
#                      author                                soldBy  \
# 0         Lindsay C. Gibson               Amazon.com Services LLC
# 1          Arthur C. Brooks               Penguin Group (USA) LLC
# ...

# %%
df.shape
# Out:
# (133102, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133102 entries, 0 to 133101
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   asin               133102 non-null  object
#  1   title              133102 non-null  object
#  2   author             132677 non-null  object
#  3   soldBy             123869 non-null  object
#  4   imgUrl             133102 non-null  object
#  5   productURL         133102 non-null  object
#  6   stars              133102 non-null  float64
#  7   reviews            133102 non-null  int64
#  8   price              133102 non-null  float64
#  9   isKindleUnlimited  133102 non-null  bool
#  10  category_id        133102 non-null  int64
#  11  isBestSeller       133102 non-null  bool
#  12  isEditorsPick      133102 non-null  bool
#  13  isGoodReadsChoice  133102 non-null  bool
#  14  publishedDate      84086 non-null   object
# ...

# %%
df.rename(columns={'asin':'id', 'stars':'rating'}, inplace=True)
df.columns
# Out:
# Index(['id', 'title', 'author', 'soldBy', 'imgUrl', 'productURL', 'rating',
#        'reviews', 'price', 'isKindleUnlimited', 'category_id', 'isBestSeller',
#        'isEditorsPick', 'isGoodReadsChoice', 'publishedDate', 'category_name'],
#       dtype='object')

# %%
df['title'].duplicated().sum()
# Out:
# np.int64(1189)

# %%
df['title'].drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id                       0
# title                    0
# author                 425
# soldBy                9233
# imgUrl                   0
# productURL               0
# rating                   0
# reviews                  0
# price                    0
# isKindleUnlimited        0
# category_id              0
# isBestSeller             0
# isEditorsPick            0
# isGoodReadsChoice        0
# publishedDate        49016
# category_name            0
# dtype: int64

# %%
df.drop(['soldBy','imgUrl','productURL','reviews','isKindleUnlimited','isBestSeller','isEditorsPick','isGoodReadsChoice'], axis=1, inplace=True)
df.head(5)
# Out:
#            id                                              title  \
# 0  B00TZE87S4  Adult Children of Emotionally Immature Parents...
# 1  B08WCKY8MB  From Strength to Strength: Finding Success, Ha...
# 2  B09KPS84CJ  Good Inside: A Guide to Becoming the Parent Yo...
# 3  B07S7QPG6J             Everything I Know About Love: A Memoir
# 4  B00N6PEQV0  The Seven Principles for Making Marriage Work:...
#
#               author  rating  price  category_id publishedDate  \
# 0  Lindsay C. Gibson     4.8   9.99            6    2015-06-01
# 1   Arthur C. Brooks     4.4  16.99            6    2022-02-15
# 2      Becky Kennedy     4.8  16.99            6    2022-09-13
# 3     Dolly Alderton     4.2   9.95            6    2020-02-25
# 4       John Gottman     4.7  13.99            6    2015-05-05
#
#                category_name
# 0  Parenting & Relationships
# 1  Parenting & Relationships
# 2  Parenting & Relationships
# 3  Parenting & Relationships
# 4  Parenting & Relationships

# %%
df.describe()
# Out:
#               rating          price    category_id
# count  133102.000000  133102.000000  133102.000000
# mean        4.404090      15.134127      16.287111
# std         0.745646      22.254986       8.416924
# min         0.000000       0.000000       1.000000
# 25%         4.400000       4.990000       9.000000
# 50%         4.500000       9.990000      16.000000
# 75%         4.700000      14.990000      23.000000
# max         5.000000     682.000000      31.000000

# %%
df[df.index == 'Parenting & Relationships']
# Out:
#                                    id  \
# Parenting & Relationships  B00TZE87S4
# Parenting & Relationships  B08WCKY8MB
# Parenting & Relationships  B09KPS84CJ
# Parenting & Relationships  B07S7QPG6J
# Parenting & Relationships  B00N6PEQV0
# ...                               ...
# Parenting & Relationships  B087CH2NLH
# Parenting & Relationships  B006D8UD4G
# Parenting & Relationships  B007W4EBPW
# Parenting & Relationships  B0CF46MX49
# Parenting & Relationships  B00AK78Q0O
#
#                                                                        title  \
# Parenting & Relationships  Adult Children of Emotionally Immature Parents...
# Parenting & Relationships  From Strength to Strength: Finding Success, Ha...
# Parenting & Relationships  Good Inside: A Guide to Becoming the Parent Yo...
# Parenting & Relationships             Everything I Know About Love: A Memoir
# Parenting & Relationships  The Seven Principles for Making Marriage Work:...
# ...
